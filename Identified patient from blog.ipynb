# %% [markdown]
# <a href="https://colab.research.google.com/github/sancha38/ML/blob/master/Identified%20patient%20from%20blog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_csv("~/.patient/dataset/train.csv",encoding = "ISO-8859-1")
df.head(5)
